# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns

sns.set_style('darkgrid')
sns.set(font_scale=1.6)

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)


# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
def trainDataLoad(market=True,news=True):
    try:
        from kaggle.competitions import twosigmanews

        env = twosigmanews.make_env()
        (market_df, news_df) = env.get_training_data()

        (market_train_df.shape, news_train_df.shape)
    except:
        print('failed to load data from kaggle, loading data from local directory.')
        if(market):
            market_df=pd.read_csv('./sampleData/market_train.csv')
            if(not news):
                return market_df
        if(news):
            news_df=pd.read_csv('./sampleData/news_train.csv')
            if(not market):
                return news_df
    print('Train data loaded!')
    return (market_df,news_df)

# %%
def loadTokens(df_col):
    from ast import literal_eval
    return [literal_eval(content)for content in news_train_df['headline_tokens'].iteritems()]

# %%
def timeCut(df,time, replace=True):
    '''
    df: dataFrame with attribute time in datatime64 format
    time: a time in string
    return df slice cutting off the time before the time provided
    '''
    df.time=pd.to_datetime(df.time)
    time=pd.Timestamp(time)
    df_slice = df[df.time>time]
    if replace:
        df=df_slice
    return df_slice

def formatCodeSet(df,field):
    '''
    df:dataframe
    field:field name of the code in the form string in set format
    return the field formatted into array
    '''
    return df[field].str.findall(f"'([\w\./]+)'")

# %% [raw]
# #Depends on the need, cut the data into smaller size for dev testing to save resources
#
# time='2012-12-31'
# # its best to get the data with a time cut
# if time:
#     market_train_df = timeCut(market_train_df,time)
#     news_train_df = timeCut(news_train_df,time)
#
# news_train_df['subjects'] = formatCodeSet(news_train_df,'subjects')
# news_train_df['audiences'] = formatCodeSet(news_train_df,'audiences')
# news_train_df['assetCodes'] = formatCodeSet(news_train_df,'assetCodes')

# %% [markdown]
# # Part 2 - News data

# %% [markdown]
# The news dataset already included many engineered features for prediction. However it would be nice to further explore the headline features with different kind of embeddings. In order to include the data in the news headlines, it would be useful to apply document embedding so that the model can "understand" the document contents and improve its prediction accordingly.

# %%
import nltk
from nltk.tokenize import RegexpTokenizer


def tokeniser_wrapper(tokeniser):
    '''
    A tokeniser wrapper proxy to handle exceptions
    '''
    def wrapped(tokeniser,text):
        try:
            return tokeniser(text)
        except:
            print('Failed tokenisation on input:',text)
            return []
    return lambda text:wrapped(tokeniser,text)
    
    
def getTokens(tokeniser, textCol, iterator=True):
    '''
    Take in a text column and then return an array of tokenised entries
    '''
    if not iterator:
        return list(map(tokeniser,textCol.as_matrix()))
    return map(tokeniser,textCol.as_matrix())

#Tokenisers
tknsr=tokeniser_wrapper(nltk.word_tokenize)
tknsr_noPunc = tokeniser_wrapper(nltk.tokenize.RegexpTokenizer('\w+').tokenize)

# %%
news_train_df['headline_tokens']=list(map(tknsr,news_train_df['headline'].as_matrix()))
# Out:
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan
# Failed tokenisation on input: nan

# %%
#Load Data
news_train_df=trainDataLoad(market=False)

#Reconstruct the token lists
from ast import literal_eval
news_train_df['headline_tokens']=news_train_df['headline_tokens'].apply(literal_eval)

# %% [markdown]
# # Data Observations

# %% [markdown]
# Before planning what to do with the new, we would first need to understand the data a bit. The sample is a smaller dataset with records starting from 2013.

# %%
def distribution(df,groupByCols,col,sort=True,percentage=True):
    count=df[groupByCols+[col]].groupby(groupByCols).count()
    if(percentage):
        count=count*100/len(df)
    if(sort):
        count=count[col].sort_values()
    return count

# %%
news_train_df.provider.count()
# Out:
# 4054316

# %% [markdown]
# There are over 4M news articles.

# %%
distribution(news_train_df,['provider'],'time')
# Out:
# provider
# CSE      0.000271
# DGP      0.002319
# ACT      0.002836
# EANS     0.003083
# ICE      0.004168
# TEN      0.004193
# FSC      0.004218
# CIS      0.005895
# JCN      0.015465
# AWP      0.018203
# ACN      0.024295
# EQS      0.052931
# BSE      0.094023
# RNS      0.416174
# ONE      0.441776
# CNW      0.450014
# HIIS     1.168187
# LSE      1.584731
# MKW      1.760593
# GNW      2.464830
# BSW      6.776162
# PRN      7.830889
# RTRS    76.874743
# Name: time, dtype: float64

# %% [markdown]
# As seen above, over 75% of the news are from RTRS and then 7.8% for PRN, 6.8% for BSW and then 2.5 for BNW and the rest has less than 10%.

# %%
providerTime=distribution(news_train_df,['provider','time'],'urgency')

# %% [markdown]
# For other news provider other than RTRS, they have only urgency number 3. For RTRS, most of the news are either 3 or 1 with only very small proportion of urgency level 2.

# %%
distribution(news_train_df,['audiences','provider'],'time')
# Out:
# audiences                                                                                                                                            provider
# ['AEN', 'DNP', 'EMK']                                                                                                                                RTRS         0.000025
# ['UKI', 'Z', 'C', 'MTL', 'T', 'O', 'SOF', 'U', 'D', 'GRO', 'M', 'GFN', 'EMK', 'OIL', 'E', 'NAT']                                                     RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'PSC', 'PEN', 'U', 'RNP', 'EMK', 'NAW', 'OIL', 'CAN', 'E', 'N']                                                           RTRS         0.000025
# ['UKI', 'Z', 'C', 'MTL', 'T', 'O', 'SOF', 'U', 'D', 'GRO', 'M', 'GFN', 'EMK', 'J', 'OIL', 'NAW', 'E', 'NAT']                                         RTRS         0.000025
# ['UKI', 'Z', 'C', 'MTL', 'T', 'O', 'SOF', 'U', 'D', 'GRO', 'M', 'EMK', 'MF', 'OIL', 'J', 'E', 'NAT']                                                 RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'PSC', 'PEN', 'U', 'RNP', 'EMK', 'PX', 'OIL', 'NAW', 'E']                                                                 RTRS         0.000025
# ['UKI', 'Z', 'C', 'MTL', 'T', 'O', 'SOF', 'U', 'D', 'GRO', 'AUP', 'M', 'J', 'OIL', 'AUF', 'MF', 'E', 'NAT']                                          RTRS         0.000025
# ['UKI', 'Z', 'C', 'MTL', 'T', 'O', 'SOF', 'U', 'D', 'GRO', 'AUP', 'M', 'EMK', 'OIL', 'AUF', 'CAN', 'E', 'NAT']                                       RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'PSC', 'PEN', 'U', 'RNP', 'NAW', 'OIL', 'AUP', 'J', 'E', 'AUF']                                                           RTRS         0.000025
# ['UKI', 'Z', 'C', 'MTL', 'T', 'O', 'SOF', 'PSC', 'U', 'D', 'GRO', 'M', 'SNS', 'OIL', 'SNI', 'E', 'NAT', 'RINVM']                                     RTRS         0.000025
# ['UKI', 'Z', 'C', 'MTL', 'T', 'O', 'SOF', 'PSC', 'U', 'D', 'GRO', 'M', 'SNS', 'OIL', 'NAW', 'SNI', 'E', 'NAT', 'RINVM']                              RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'PSC', 'PEN', 'U', 'RNP', 'NAW', 'OIL', 'E', 'HGN']                                                                       RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'PSC', 'PEN', 'U', 'RNP', 'NAW', 'OIL', 'E', 'SI', 'N']                                                                   RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'PSC', 'PEN', 'U', 'RNP', 'NAW', 'OIL', 'E', 'SI', 'RINVM']                                                               RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'PSC', 'PEN', 'U', 'RNP', 'NAW', 'OIL', 'J', 'CAN', 'E', 'SI']                                                            RTRS         0.000025
# ['UKI', 'Z', 'C', 'MTL', 'T', 'O', 'SOF', 'PSC', 'U', 'D', 'GRO', 'M', 'OIL', 'E', 'NAT', 'N']                                                       RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'PSC', 'PEN', 'U', 'RNP', 'NAW', 'OIL', 'J', 'PTD', 'E', 'NAT']                                                           RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'PSC', 'PEN', 'U', 'RNP', 'NAW', 'OIL', 'SF', 'CAN', 'E']                                                                 RTRS         0.000025
# ['UKI', 'Z', 'C', 'MTL', 'T', 'O', 'SOF', 'U', 'D', 'GRO', 'M', 'GFN', 'J', 'OIL', 'NAW', 'E', 'NAT']                                                RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'PSC', 'PEN', 'U', 'RNP', 'NAW', 'OIL', 'SNS', 'E']                                                                       RTRS         0.000025
# ['UKI', 'Z', 'C', 'MTL', 'T', 'O', 'SOF', 'U', 'D', 'GRO', 'M', 'SNS', 'OIL', 'SNI', 'E', 'NAT']                                                     RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'PSC', 'PEN', 'U', 'OIL', 'RNP', 'SNS', 'J', 'NAW', 'SNI', 'E', 'SI']                                                     RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'PSC', 'PEN', 'U', 'ELN', 'EMK', 'NAW', 'OIL', 'E']                                                                       RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'PSC', 'PEN', 'U', 'ELN', 'OIL', 'RNP', 'J', 'SNS', 'NAW', 'SNI', 'E']                                                    RTRS         0.000025
# ['UKI', 'Z', 'C', 'MTL', 'T', 'SOF', 'PSC', 'GRO', 'D', 'M', 'EMK', 'AUP', 'E', 'AUF']                                                               RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'PSC', 'PEN', 'U', 'ELN', 'RNP', 'EMK', 'NAW', 'OIL', 'J', 'E']                                                           RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'PSC', 'PEN', 'U', 'ELN', 'RNP', 'NAW', 'OIL', 'AUP', 'E', 'AUF']                                                         RTRS         0.000025
# ['UKI', 'Z', 'C', 'MTL', 'T', 'SOF', 'GRO', 'D', 'CAN', 'E', 'AUF']                                                                                  RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'PSC', 'PEN', 'U', 'EMK', 'NAW', 'OIL', 'SP', 'CAN', 'E']                                                                 RTRS         0.000025
# ['UKI', 'Z', 'C', 'MTL', 'T', 'SOF', 'DNP', 'PSC', 'GRO', 'U', 'D', 'M', 'EMK', 'RNP', 'NAW', 'E']                                                   RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'PSC', 'PEN', 'U', 'GFN', 'RNP', 'NAW', 'OIL', 'E', 'SI']                                                                 RTRS         0.000025
# ['UKI', 'Z', 'C', 'MTL', 'T', 'SOF', 'DNP', 'PSC', 'GRO', 'D', 'M', 'EMK', 'RNP', 'SNS', 'SNI', 'E']                                                 RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'PSC', 'PEN', 'U', 'NAW', 'OIL', 'SP', 'CAN', 'E']                                                                        RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'PSC', 'PEN', 'U', 'OIL', 'RNP', 'EMK', 'J', 'NAW', 'AUP', 'CAN', 'E', 'AUF']                                             RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'PSC', 'PEN', 'U', 'OIL', 'RNP', 'EMK', 'SNS', 'NAW', 'SNI', 'E']                                                         RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'PSC', 'PEN', 'U', 'OIL', 'RNP', 'IF', 'NAW', 'J', 'PX', 'E', 'SI']                                                       RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'PSC', 'PEN', 'U', 'OIL', 'RNP', 'J', 'NAW', 'E', 'SI']                                                                   RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'PSC', 'PEN', 'U', 'OIL', 'RNP', 'J', 'SNS', 'NAW', 'SNI', 'E', 'SI']                                                     RTRS         0.000025
# ['UKI', 'Z', 'C', 'MTL', 'T', 'PCM', 'SOF', 'DNP', 'PSC', 'GRO', 'D', 'M', 'EMK', 'RNP', 'J', 'E', 'SI']                                             RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'PSC', 'PEN', 'U', 'OIL', 'RNP', 'SNS', 'NAW', 'J', 'SNI', 'E', 'SI']                                                     RTRS         0.000025
# ['UKI', 'Z', 'C', 'MTL', 'U', 'EMK', 'NAW', 'J', 'AUP', 'E', 'AUF']                                                                                  RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'PSC', 'PEN', 'U', 'RNP', 'NAW', 'OIL', 'SNS', 'SNI', 'E']                                                                RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'PSC', 'PEN', 'U', 'RNP', 'SNS', 'OIL', 'NAW', 'SNI', 'E']                                                                RTRS         0.000025
# ['UKI', 'Z', 'C', 'MTL', 'T', 'O', 'SOF', 'PSC', 'U', 'D', 'GRO', 'M', 'EMK', 'MF', 'OIL', 'J', 'E', 'NAT']                                          RTRS         0.000025
# ['PCO', 'PCU', 'O', 'ELE', 'U', 'RNP', 'J', 'E']                                                                                                     RTRS         0.000025
# ['PCO', 'PCU', 'O', 'ELE', 'U', 'RNP', 'OIL', 'CAN', 'E']                                                                                            RTRS         0.000025
# ['UKI', 'Z', 'C', 'MTL', 'T', 'O', 'SOF', 'PSC', 'U', 'D', 'GRO', 'ELN', 'M', 'NAW', 'OIL', 'E', 'NAT']                                              RTRS         0.000025
# ['PCO', 'PCU', 'O', 'ELN', 'RNP', 'OIL']                                                                                                             RTRS         0.000025
# ['PCO', 'PCU', 'O', 'MD', 'DNP', 'PSC', 'PEN', 'U', 'GFN', 'RNP', 'NAW', 'OIL', 'CAN', 'E']                                                          RTRS         0.000025
# ['PCO', 'PCU', 'O', 'MD', 'U', 'GFN', 'RNP', 'CAN', 'E', 'AUF']                                                                                      RTRS         0.000025
# ['PCO', 'PCU', 'O', 'PHD', 'DNP', 'PSC', 'U', 'ELN', 'RNP', 'NAW', 'E', 'SI']                                                                        RTRS         0.000025
# ['PCO', 'PCU', 'O', 'PSC', 'PEN', 'ELN', 'RNP', 'EMK', 'OIL', 'E']                                                                                   RTRS         0.000025
# ['PCO', 'PCU', 'O', 'PSC', 'PEN', 'ELN', 'RNP', 'OIL', 'E']                                                                                          RTRS         0.000025
# ['PCO', 'PCU', 'O', 'PSC', 'PEN', 'EMK', 'OIL', 'E']                                                                                                 RTRS         0.000025
# ['PCO', 'PCU', 'O', 'PSC', 'PEN', 'OIL', 'E']                                                                                                        RTRS         0.000025
# ['UKI', 'Z', 'C', 'MTL', 'T', 'O', 'SOF', 'PSC', 'U', 'D', 'GRO', 'AUP', 'M', 'OIL', 'AUF', 'E', 'NAT']                                              RTRS         0.000025
# ['PCO', 'PCU', 'O', 'PSC', 'PEN', 'RNP', 'OIL', 'CAN', 'E']                                                                                          RTRS         0.000025
# ['PCO', 'PCU', 'O', 'PSC', 'PEN', 'RON', 'RNP', 'OIL', 'E']                                                                                          RTRS         0.000025
# ['PCO', 'PCU', 'O', 'PSC', 'PEN', 'U', 'RNP', 'EMK', 'NAW', 'OIL', 'E']                                                                              RTRS         0.000025
# ['PCO', 'PCU', 'O', 'PSC', 'PEN', 'U', 'RNP', 'NAW', 'OIL', 'CAN', 'E', 'SI']                                                                        RTRS         0.000025
# ['UKI', 'Z', 'C', 'MTL', 'T', 'O', 'SOF', 'PSC', 'U', 'D', 'GRO', 'M', 'EMK', 'OIL', 'SF', 'E', 'NAT', 'RINVM']                                      RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'PSC', 'PEN', 'U', 'RNP', 'RX', 'NAW', 'OIL', 'E']                                                                        RTRS         0.000025
# ['PCO', 'PCU', 'O', 'ELE', 'PSC', 'PEN', 'U', 'RNP', 'EMK', 'NAW', 'AUP', 'E', 'AUF']                                                                RTRS         0.000025
# ['UKI', 'Z', 'C', 'MTL', 'T', 'O', 'SOF', 'PSC', 'U', 'D', 'GRO', 'M', 'EMK', 'SNS', 'OIL', 'J', 'SNI', 'E', 'NAT']                                  RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'PSC', 'RDN', 'PEN', 'U', 'RNP', 'NAW', 'OIL', 'E']                                                                       RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'PSC', 'RNP', 'J', 'E']                                                                                                   RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'PSC', 'U', 'ELN', 'GFN', 'EMK', 'RNP', 'NAW', 'E']                                                                       RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'PSC', 'U', 'ELN', 'RNP', 'EMK', 'NAW', 'E']                                                                              RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'PSC', 'U', 'ELN', 'RNP', 'EMK', 'NAW', 'OIL', 'E']                                                                       RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'PSC', 'U', 'ELN', 'RNP', 'J', 'NAW', 'E']                                                                                RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'PSC', 'U', 'ELN', 'RNP', 'NAW', 'AUP', 'E', 'AUF']                                                                       RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'PSC', 'U', 'ELN', 'RNP', 'NAW', 'CAN', 'E']                                                                              RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'PSC', 'U', 'ELN', 'RNP', 'NAW', 'OIL', 'CAN', 'E']                                                                       RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'PSC', 'U', 'GNN', 'ELN', 'RNP', 'EMK', 'NAW', 'E']                                                                       RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'PSC', 'U', 'RNP', 'EMK', 'NAW', 'E']                                                                                     RTRS         0.000025
# ['UKI', 'Z', 'C', 'MTL', 'T', 'O', 'SOF', 'PSC', 'U', 'D', 'GRO', 'M', 'J', 'OIL', 'E', 'NAT', 'RINVM']                                              RTRS         0.000025
# ['UKI', 'Z', 'C', 'MTL', 'T', 'O', 'SOF', 'PSC', 'U', 'D', 'GRO', 'M', 'GFN', 'NAW', 'OIL', 'E', 'NAT']                                              RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'PSC', 'U', 'RNP', 'NAW', 'OIL', 'E', 'SI']                                                                               RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'PSC', 'U', 'RNP', 'PX', 'OIL', 'NAW', 'E']                                                                               RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'U', 'ELN', 'NAW', 'E']                                                                                                   RTRS         0.000025
# ['UKI', 'Z', 'C', 'MTL', 'T', 'O', 'SOF', 'PSC', 'U', 'D', 'GRO', 'M', 'EMK', 'SNS', 'OIL', 'SNI', 'E', 'NAT']                                       RTRS         0.000025
# ['UKI', 'Z', 'C', 'MTL', 'T', 'O', 'SOF', 'PSC', 'U', 'D', 'GRO', 'M', 'EMK', 'OIL', 'SF', 'E', 'NAT']                                               RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'PSC', 'PEN', 'RNP', 'OIL', 'SF', 'CAN', 'E']                                                                             RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'PSC', 'PEN', 'RNP', 'OIL', 'E', 'N']                                                                                     RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'PSC', 'PEN', 'RNP', 'J', 'OIL', 'E', 'SI']                                                                               RTRS         0.000025
# ['PCO', 'PCU', 'MD', 'O', 'DNP', 'PSC', 'PEN', 'U', 'RNP', 'NAW', 'OIL', 'E']                                                                        RTRS         0.000025
# ['PCO', 'PCU', 'MNI', 'U', 'RNP', 'CAN', 'E']                                                                                                        RTRS         0.000025
# ['PCO', 'PCU', 'MNI', 'U', 'RNP', 'NAW', 'E', 'NAT']                                                                                                 RTRS         0.000025
# ['PCO', 'PCU', 'O', 'CNR', 'DNP', 'GNWN', 'PSC', 'PEN', 'U', 'RNP', 'NAW', 'OIL', 'E']                                                               RTRS         0.000025
# ['PCO', 'PCU', 'O', 'CNR', 'DNP', 'PSC', 'PEN', 'CNW', 'U', 'RNP', 'NAW', 'OIL', 'CAN', 'E']                                                         RTRS         0.000025
# ['UKI', 'Z', 'C', 'PCO', 'MTL', 'PCU', 'DNP', 'PSC', 'U', 'RNP', 'EMK', 'NAW', 'AUP', 'CAN', 'E', 'AUF', 'RINVM']                                    RTRS         0.000025
# ['UKI', 'Z', 'C', 'PCO', 'MTL', 'PCU', 'DNP', 'PSC', 'U', 'RNP', 'EMK', 'J', 'NAW', 'AUP', 'CAN', 'E', 'AUF']                                        RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'ELE', 'CZS', 'PSC', 'U', 'PEN', 'RNP', 'EMK', 'NAW', 'E']                                                                RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'ELE', 'PEN', 'U', 'ELN', 'NAW', 'E']                                                                                     RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'ELE', 'PEN', 'U', 'ELN', 'NAW', 'OIL', 'E']                                                                              RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'ELE', 'PEN', 'U', 'GNN', 'EMK', 'NAW', 'E']                                                                              RTRS         0.000025
# ['UKI', 'Z', 'C', 'PCO', 'MTL', 'PCU', 'DNP', 'PSC', 'RNP', 'IF', 'EMK', 'AUP', 'E', 'AUF']                                                          RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'ELE', 'PSC', 'PEN', 'GFN', 'EMK', 'RNP', 'OIL', 'E']                                                                     RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'ELE', 'PSC', 'PEN', 'GFN', 'RNP', 'E']                                                                                   RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'ELE', 'PSC', 'PEN', 'GNN', 'RNP', 'EMK', 'E']                                                                            RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'ELE', 'PSC', 'PEN', 'RNP', 'EMK', 'OIL', 'CAN', 'E']                                                                     RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'ELE', 'PSC', 'PEN', 'RNP', 'EMK', 'PX', 'E', 'N']                                                                        RTRS         0.000025
# ['UKI', 'Z', 'C', 'PCO', 'MTL', 'PCU', 'DNP', 'PSC', 'U', 'RNP', 'EMK', 'NAW', 'E', 'SI']                                                            RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'ELE', 'PSC', 'PEN', 'U', 'ELN', 'GFN', 'RNP', 'NAW', 'AUP', 'E', 'AUF']                                                  RTRS         0.000025
# ['PCO', 'PCU', 'ELE', 'PSC', 'RNP', 'E']                                                                                                             RTRS         0.000025
# ['PCO', 'PCU', 'DNP', 'U', 'RNP', 'NAW', 'E']                                                                                                        RTRS         0.000025
# ['PCO', 'PCU', 'DNP', 'PSC', 'U', 'RNP', 'NAW', 'PX', 'AUP', 'E', 'AUF']                                                                             RTRS         0.000025
# ['PCO', 'PCU', 'DNP', 'PSC', 'U', 'RNP', 'NAW', 'SNS', 'AUP', 'SNI', 'E', 'AUF']                                                                     RTRS         0.000025
# ['PCO', 'PCU', 'DNP', 'PSC', 'U', 'RNP', 'NAW', 'SNS', 'E', 'N']                                                                                     RTRS         0.000025
# ['PCO', 'PCU', 'DNP', 'PSC', 'U', 'RNP', 'NAW', 'SNS', 'SNI', 'FMA', 'E']                                                                            RTRS         0.000025
# ['PCO', 'PCU', 'DNP', 'PSC', 'U', 'RNP', 'NAW', 'SP', 'CAN', 'E']                                                                                    RTRS         0.000025
# ['PCO', 'PCU', 'DNP', 'PSC', 'U', 'RNP', 'PX', 'E']                                                                                                  RTRS         0.000025
# ['UKI', 'Z', 'C', 'PCO', 'MTL', 'PCU', 'PSC', 'RNP', 'EMK', 'AUP', 'E', 'AUF']                                                                       RTRS         0.000025
# ['PCO', 'PCU', 'DNP', 'PSC', 'U', 'RNP', 'RX', 'SNS', 'J', 'NAW', 'SNI', 'E']                                                                        RTRS         0.000025
# ['PCO', 'PCU', 'DNP', 'PSC', 'U', 'RNP', 'SNS', 'NAW', 'SF', 'SNI', 'E']                                                                             RTRS         0.000025
# ['PCO', 'PCU', 'DNP', 'PSC', 'U', 'RNP', 'SNS', 'NAW', 'SNI', 'CAN', 'E', 'SI']                                                                      RTRS         0.000025
# ['PCO', 'PCU', 'DNP', 'PSC', 'U', 'RNP', 'SNS', 'NAW', 'SNI', 'E', 'RINVM']                                                                          RTRS         0.000025
# ['PCO', 'PCU', 'DNP', 'PSC', 'U', 'RON', 'RNP', 'NAW', 'E']                                                                                          RTRS         0.000025
# ['PCO', 'PCU', 'DNP', 'U', 'EMK', 'NAW', 'CAN', 'E']                                                                                                 RTRS         0.000025
# ['PCO', 'PCU', 'DNP', 'U', 'NAW', 'AUP', 'CAN', 'E', 'AUF']                                                                                          RTRS         0.000025
# ['PCO', 'PCU', 'DNP', 'U', 'NAW', 'E', 'SI']                                                                                                         RTRS         0.000025
# ['UKI', 'Z', 'C', 'PCO', 'MTL', 'PCU', 'DNP', 'PSC', 'U', 'RNP', 'NAW', 'E']                                                                         RTRS         0.000025
# ['UKI', 'Z', 'C', 'PCO', 'MTL', 'PCU', 'DNP', 'PSC', 'U', 'RNP', 'EMK', 'PX', 'NAW', 'E']                                                            RTRS         0.000025
# ['PCO', 'PCU', 'DNP', 'U', 'SNS', 'NAW', 'SNI', 'E']                                                                                                 RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'ELE', 'PSC', 'PEN', 'U', 'ELN', 'RNP', 'EMK', 'NAW', 'AUP', 'E', 'AUF']                                                  RTRS         0.000025
# ['UKI', 'Z', 'C', 'PCO', 'MTL', 'PCM', 'SOF', 'DNP', 'PSC', 'GRO', 'RNP', 'EMK', 'E']                                                                RTRS         0.000025
# ['UKI', 'Z', 'C', 'PCO', 'MTL', 'PCM', 'O', 'SOF', 'DNP', 'PSC', 'PEN', 'PCU', 'GRO', 'U', 'RNP', 'EMK', 'NAW', 'OIL', 'CAN', 'E']                   RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'ELE', 'RDN', 'PSC', 'U', 'PEN', 'RNP', 'NAW', 'E']                                                                       RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'PEN', 'MNI', 'U', 'NAW', 'OIL', 'E']                                                                                     RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'PEN', 'U', 'ELN', 'EMK', 'NAW', 'OIL', 'E']                                                                              RTRS         0.000025
# ['UKI', 'Z', 'C', 'PCO', 'MTL', 'AFN', 'PCU', 'SOF', 'DNP', 'PSC', 'GRO', 'U', 'RNP', 'EMK', 'NAW', 'SF', 'CAN', 'E']                                RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'PEN', 'U', 'ELN', 'OIL', 'J', 'NAW', 'E']                                                                                RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'PEN', 'U', 'EMK', 'NAW', 'OIL', 'CAN', 'E']                                                                              RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'PEN', 'U', 'NAW', 'OIL', 'AUP', 'E', 'AUF']                                                                              RTRS         0.000025
# ['UKI', 'Z', 'C', 'PCO', 'MTL', 'AFN', 'DNP', 'PSC', 'AUP', 'RNP', 'EMK', 'SF', 'E', 'AUF']                                                          RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'PSC', 'ELE', 'PEN', 'GFN', 'RNP', 'E']                                                                                   RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'PSC', 'PEN', 'ELN', 'RNP', 'J', 'OIL', 'E']                                                                              RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'PSC', 'PEN', 'GFN', 'EMK', 'RNP', 'OIL', 'AUP', 'E', 'AUF']                                                              RTRS         0.000025
# ['UKI', 'Z', 'C', 'PCO', 'AFN', 'MTL', 'T', 'DNP', 'PSC', 'D', 'RNP', 'EMK', 'AUP', 'SF', 'E', 'AUF']                                                RTRS         0.000025
# ['UKI', 'Z', 'C', 'PCO', 'AFN', 'MTL', 'PCU', 'DNP', 'PSC', 'U', 'RNP', 'EMK', 'NAW', 'CAN', 'E']                                                    RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'PSC', 'PEN', 'OIL', 'RNP', 'SNS', 'J', 'SNI', 'E']                                                                       RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'PSC', 'PEN', 'RNP', 'EMK', 'J', 'OIL', 'E']                                                                              RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'PSC', 'PEN', 'RNP', 'EMK', 'OIL', 'SNS', 'E']                                                                            RTRS         0.000025
# ['UKI', 'Z', 'C', 'PCO', 'AFN', 'MTL', 'DNP', 'PSC', 'RNP', 'EMK', 'AUP', 'SF', 'E', 'AUF']                                                          RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'ELE', 'PSC', 'U', 'ELN', 'RNP', 'NAW', 'CAN', 'E']                                                                       RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'ELE', 'PSC', 'PEN', 'U', 'RNP', 'PX', 'NAW', 'AUP', 'E', 'AUF']                                                          RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'ELE', 'PSC', 'PEN', 'U', 'RNP', 'NAW', 'SF', 'E']                                                                        RTRS         0.000025
# ['UKI', 'Z', 'C', 'PCO', 'MTL', 'DNP', 'PSC', 'RNP', 'EMK', 'E', 'N']                                                                                RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'ELE', 'PSC', 'PEN', 'U', 'ELN', 'RNP', 'NAW', 'CAN', 'E']                                                                RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'ELE', 'PSC', 'PEN', 'U', 'ELN', 'RNP', 'NAW', 'J', 'E']                                                                  RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'ELE', 'PSC', 'PEN', 'U', 'ELN', 'RNP', 'NAW', 'OIL', 'CAN', 'E']                                                         RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'ELE', 'PSC', 'PEN', 'U', 'GFN', 'EMK', 'RNP', 'J', 'NAW', 'E']                                                           RTRS         0.000025
# ['UKI', 'Z', 'C', 'PCO', 'MTL', 'PCM', 'O', 'SOF', 'DNP', 'ELE', 'PSC', 'PEN', 'GRO', 'U', 'RNP', 'EMK', 'NAW', 'AUP', 'E', 'AUF']                   RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'ELE', 'PSC', 'PEN', 'U', 'GFN', 'RNP', 'SNS', 'NAW', 'SNI', 'E']                                                         RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'ELE', 'PSC', 'PEN', 'U', 'GNN', 'RNP', 'NAW', 'E']                                                                       RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'ELE', 'PSC', 'PEN', 'U', 'OIL', 'RNP', 'SNS', 'NAW', 'SNI', 'E']                                                         RTRS         0.000025
# ['PCO', 'PCU', 'O', 'U', 'E', 'RNP', 'ND']                                                                                                           RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'ELE', 'PSC', 'PEN', 'U', 'P', 'RNP', 'EMK', 'NAW', 'E']                                                                  RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'ELE', 'PSC', 'PEN', 'U', 'RNP', 'EMK', 'NAW', 'E', 'SI']                                                                 RTRS         0.000025
# ['UKI', 'Z', 'C', 'PCO', 'MTL', 'O', 'SOF', 'DNP', 'ELE', 'PSC', 'PEN', 'GRO', 'RNP', 'EMK', 'AUP', 'E', 'AUF']                                      RTRS         0.000025
# ['UKI', 'Z', 'C', 'PCO', 'MTL', 'O', 'DNP', 'PSC', 'PEN', 'RNP', 'EMK', 'J', 'OIL', 'AUP', 'E', 'AUF']                                               RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'ELE', 'PSC', 'PEN', 'U', 'RNP', 'EMK', 'NAW', 'PTD', 'E', 'NAT']                                                         RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'ELE', 'PSC', 'PEN', 'U', 'RNP', 'EMK', 'NAW', 'PX', 'CAN', 'E']                                                          RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'ELE', 'PSC', 'PEN', 'U', 'RNP', 'EMK', 'PX', 'NAW', 'AUP', 'E', 'AUF']                                                   RTRS         0.000025
# ['PCO', 'PCU', 'O', 'DNP', 'ELE', 'PSC', 'PEN', 'U', 'RNP', 'EMK', 'SNS', 'J', 'NAW', 'SNI', 'E']                                                    RTRS         0.000025
# ['UKI', 'Z', 'C', 'PCO', 'MTL', 'DNP', 'PSC', 'RNP', 'EMK', 'SNS', 'AUP', 'SNI', 'E', 'AUF']                                                         RTRS         0.000025
# ['UKI', 'Z', 'C', 'PCO', 'MTL', 'O', 'SOF', 'DNP', 'PSC', 'PEN', 'GRO', 'RNP', 'EMK', 'OIL', 'E', 'SI']                                              RTRS         0.000025
# ['PCO', 'PCU', 'O', 'U', 'E', 'RNP', 'OIL', 'ND']                                                                                                    RTRS         0.000025
# ['PCO', 'PCU', 'O', 'U', 'ELN', 'RNP', 'CAN', 'E', 'NAT']                                                                                            RTRS         0.000025
# ['PCO', 'PCU', 'O', 'U', 'ELN', 'RNP', 'E', 'NAT']                                                                                                   RTRS         0.000025
# ['PCO', 'S', 'DNP', 'PSC', 'RNP', 'PSP', 'SNS', 'E']                                                                                                 RTRS         0.000025
# ['PCO', 'S', 'DNP', 'PSC', 'U', 'RNP', 'PSP', 'NAW', 'J', 'E']                                                                                       RTRS         0.000025
# ['PCO', 'S', 'G', 'PCU', 'U', 'RNP', 'E']                                                                                                            RTRS         0.000025
# ['PCO', 'S', 'O', 'DNP', 'PSC', 'PEN', 'RNP', 'PSP', 'OIL', 'E']                                                                                     RTRS         0.000025
# ['PCO', 'S', 'PCU', 'DNP', 'PSC', 'MNI', 'U', 'RNP', 'PSP', 'NAW', 'E']                                                                              RTRS         0.000025
# ['PCO', 'S', 'PCU', 'DNP', 'PSC', 'U', 'GFN', 'EMK', 'RNP', 'NAW', 'PSP', 'E']                                                                       RTRS         0.000025
# ['PCO', 'S', 'PCU', 'DNP', 'PSC', 'U', 'RNP', 'EMK', 'PSP', 'NAW', 'AUP', 'E', 'AUF']                                                                RTRS         0.000025
# ['UKI', 'Z', 'C', 'MTL', 'SOF', 'PSC', 'U', 'EMK', 'NAW', 'E', 'SI', 'RINVM']                                                                        RTRS         0.000025
# ['PCO', 'S', 'PCU', 'DNP', 'PSC', 'U', 'RNP', 'IF', 'PSP', 'NAW', 'E', 'SI']                                                                         RTRS         0.000025
# ['PCO', 'S', 'PCU', 'DNP', 'PSC', 'U', 'RNP', 'PSP', 'NAW', 'AUP', 'E', 'AUF', 'ND']                                                                 RTRS         0.000025
# ['PCO', 'S', 'PCU', 'DNP', 'PSC', 'U', 'RNP', 'PSP', 'NAW', 'E', 'ND']                                                                               RTRS         0.000025
# ['PCO', 'S', 'PCU', 'O', 'DNP', 'PSC', 'PEN', 'U', 'OIL', 'RNP', 'PSP', 'NAW', 'SNS', 'SNI', 'E']                                                    RTRS         0.000025
# ['UKI', 'Z', 'C', 'MTL', 'SOF', 'DNP', 'GRO', 'EMK']                                                                                                 RTRS         0.000025
# ['PCO', 'S', 'PCU', 'U', 'RNP', 'SNS', 'E']                                                                                                          RTRS         0.000025
# ['PCO', 'S', 'T', 'DNP', 'PSC', 'D', 'RNP', 'EMK', 'PSP', 'E']                                                                                       RTRS         0.000025
# ['PCO', 'S', 'T', 'PCU', 'DNP', 'PSC', 'U', 'D', 'RNP', 'PSP', 'NAW', 'PTD', 'E', 'NAT']                                                             RTRS         0.000025
# ['PCO', 'SI', 'DNP', 'PSC', 'RNP', 'AUP', 'E', 'GER', 'AUF']                                                                                         RTRS         0.000025
# ['UKI', 'Z', 'C', 'MTL', 'SOF', 'PSC', 'U', 'GRO', 'EMK', 'NAW', 'E']                                                                                RTRS         0.000025
# ['PCO', 'SI', 'DNP', 'PSC', 'RNP', 'IF', 'AUP', 'E', 'AUF']                                                                                          RTRS         0.000025
# ['PCO', 'S', 'DNP', 'PSC', 'RNP', 'GFN', 'PSP', 'E']                                                                                                 RTRS         0.000025
# ['PCO', 'S', 'DNP', 'PSC', 'RNP', 'EMK', 'PSP', 'J', 'E', 'SI']                                                                                      RTRS         0.000025
# ['PCO', 'PSC', 'RON', 'RNP', 'EMK', 'E']                                                                                                             RTRS         0.000025
# ['PCO', 'PSC', 'U', 'D', 'RNP', 'E', 'NAT']                                                                                                          RTRS         0.000025
# ['PCO', 'PSC', 'U', 'D', 'RNP', 'EMK', 'E', 'NAT']                                                                                                   RTRS         0.000025
# ['PCO', 'PSC', 'U', 'NAW', 'E']                                                                                                                      RTRS         0.000025
# ['PCO', 'PSC', 'U', 'RNP', 'EMK', 'J', 'E']                                                                                                          RTRS         0.000025
# ['UKI', 'Z', 'C', 'MTL', 'T', 'AFN', 'O', 'SOF', 'PSC', 'U', 'D', 'GRO', 'M', 'J', 'OIL', 'NAW', 'SF', 'E', 'NAT']                                   RTRS         0.000025
# ['PCO', 'RCE', 'PCU', 'DNP', 'PSC', 'U', 'RNP', 'NAW', 'E']                                                                                          RTRS         0.000025
# ['PCO', 'RCE', 'T', 'PCU', 'DNP', 'PSC', 'U', 'D', 'M', 'RNP', 'NAW', 'PTD', 'E']                                                                    RTRS         0.000025
# ['PCO', 'RNP', 'IF', 'J', 'E']                                                                                                                       RTRS         0.000025
# ['UKI', 'Z', 'C', 'MTL', 'T', 'AFN', 'O', 'SOF', 'G', 'PSC', 'U', 'D', 'GRO', 'M', 'OIL', 'SF', 'E', 'NAT']                                          RTRS         0.000025
# ['PCO', 'RNP', 'J', 'E', 'SI']                                                                                                                       RTRS         0.000025
# ['UKI', 'Z', 'C', 'MTL', 'T', 'AFN', 'O', 'SOF', 'G', 'PSC', 'U', 'D', 'GRO', 'M', 'EMK', 'J', 'OIL', 'E', 'NAT']                                    RTRS         0.000025
# ['PCO', 'RNP', 'SNS', 'J', 'SNI', 'E']                                                                                                               RTRS         0.000025
# ['PCO', 'S', 'AFN', 'PCU', 'DNP', 'PSC', 'U', 'RNP', 'PSP', 'NAW', 'E']                                                                              RTRS         0.000025
# ['PCO', 'S', 'DNP', 'PSC', 'BRS', 'RNP', 'EMK', 'PSP', 'E']                                                                                          RTRS         0.000025
# ['PCO', 'S', 'DNP', 'PSC', 'RNP', 'EMK', 'PSP', 'E', 'N']                                                                                            RTRS         0.000025
# ['UKI', 'Z', 'C', 'MTL', 'T', 'AFN', 'O', 'SOF', 'DNP', 'PSC', 'PEN', 'U', 'D', 'GRO', 'M', 'EMK', 'RNP', 'OIL', 'E', 'NAT']                         RTRS         0.000025
# ['UKI', 'Z', 'C', 'MTL', 'T', 'AFN', 'O', 'SOF', 'DNP', 'PSC', 'PEN', 'GRO', 'D', 'GFN', 'M', 'RNP', 'OIL', 'E']                                     RTRS         0.000025
# ['PCO', 'SI', 'O', 'DNP', 'ELE', 'PSC', 'PEN', 'ELN', 'RNP', 'AUP', 'E', 'AUF']                                                                      RTRS         0.000025
# ['PCO', 'SI', 'O', 'DNP', 'ELE', 'PSC', 'PEN', 'ELN', 'RNP', 'EMK', 'AUP', 'E', 'AUF']                                                               RTRS         0.000025
# ['PCO', 'SI', 'O', 'DNP', 'ELE', 'PSC', 'PEN', 'RNP', 'EMK', 'AUP', 'E', 'AUF']                                                                      RTRS         0.000025
# ['PCO', 'SNI', 'PCU', 'DNP', 'PSC', 'U', 'RNP', 'NAW', 'J', 'AUP', 'SNS', 'E', 'AUF']                                                                RTRS         0.000025
# ['UKI', 'Z', 'C', 'MTL', 'PSC', 'U', 'EMK', 'NAW', 'AUP', 'SNS', 'CAN', 'E', 'AUF', 'RINVM']                                                         RTRS         0.000025
# ['PCO', 'SNI', 'PCU', 'O', 'DNP', 'PSC', 'PEN', 'U', 'OIL', 'RNP', 'J', 'NAW', 'SNS', 'E', 'SI']                                                     RTRS         0.000025
# ['PCO', 'SNI', 'PCU', 'O', 'DNP', 'PSC', 'PEN', 'U', 'RNP', 'OIL', 'SNS', 'E']                                                                       RTRS         0.000025
# ['PCO', 'SNI', 'SI', 'PCU', 'DNP', 'PSC', 'U', 'RNP', 'NAW', 'AUP', 'SNS', 'E', 'AUF']                                                               RTRS         0.000025
# ['PCO', 'SNI', 'T', 'D', 'RNP', 'SNS', 'E']                                                                                                          RTRS         0.000025
# ['PCO', 'SNI', 'T', 'O', 'DNP', 'PSC', 'PEN', 'D', 'RNP', 'EMK', 'OIL', 'AUP', 'SNS', 'E', 'AUF']                                                    RTRS         0.000025
# ['PCO', 'SNI', 'T', 'PCU', 'DNP', 'PSC', 'D', 'RNP', 'SNS', 'E']                                                                                     RTRS         0.000025
# ['PCO', 'SNI', 'T', 'PCU', 'DNP', 'PSC', 'U', 'D', 'M', 'RNP', 'NAW', 'PTD', 'SNS', 'E']                                                             RTRS         0.000025
# ['PCO', 'SNI', 'T', 'PCU', 'DNP', 'PSC', 'U', 'D', 'RNP', 'NAW', 'SNS', 'E', 'RINVM']                                                                RTRS         0.000025
# ['PCO', 'SNI', 'T', 'PCU', 'DNP', 'PSC', 'U', 'D', 'RNP', 'NAW', 'SNS', 'E']                                                                         RTRS         0.000025
# ['PCO', 'SNI', 'T', 'PCU', 'U', 'D', 'RNP', 'SNS', 'E']                                                                                              RTRS         0.000025
# ['PCO', 'SWI', 'PCU', 'DNP', 'PSC', 'U', 'RNP', 'EMK', 'NAW', 'E', 'GER', 'OE']                                                                      RTRS         0.000025
# ['PCO', 'T', 'BX', 'PSC', 'DNP', 'U', 'D', 'M', 'EMK', 'RNP', 'NAW', 'PTD', 'E']                                                                     RTRS         0.000025
# ['PCO', 'T', 'BX', 'PSC', 'DNP', 'U', 'D', 'RNP', 'EMK', 'NAW', 'E']                                                                                 RTRS         0.000025
# ['PCO', 'T', 'D', 'M', 'RNP', 'E', 'AUF']                                                                                                            RTRS         0.000025
# ['UKI', 'Z', 'C', 'MTL', 'PSC', 'EMK', 'J', 'AUP', 'E', 'AUF']                                                                                       RTRS         0.000025
# ['PCO', 'SNI', 'O', 'RNP', 'SNS', 'E']                                                                                                               RTRS         0.000025
# ['PCO', 'SNI', 'O', 'PSC', 'PEN', 'RNP', 'OIL', 'SNS', 'E']                                                                                          RTRS         0.000025
# ['PCO', 'SNI', 'O', 'DNP', 'PSC', 'PEN', 'RNP', 'OIL', 'AUP', 'SNS', 'E', 'AUF']                                                                     RTRS         0.000025
# ['PCO', 'SNI', 'DNP', 'PSC', 'U', 'RNP', 'NAW', 'SNS', 'E']                                                                                          RTRS         0.000025
# ['PCO', 'SI', 'O', 'DNP', 'ELE', 'PSC', 'PEN', 'RNP', 'J', 'AUP', 'E', 'AUF']                                                                        RTRS         0.000025
# ['PCO', 'SI', 'O', 'RNP', 'OIL', 'E', 'AUF']                                                                                                         RTRS         0.000025
# ['PCO', 'SI', 'PCU', 'DNP', 'PSC', 'U', 'GFN', 'EMK', 'RNP', 'NAW', 'J', 'AUP', 'E', 'AUF']                                                          RTRS         0.000025
# ['PCO', 'SI', 'PCU', 'DNP', 'PSC', 'U', 'RNP', 'IF', 'J', 'NAW', 'AUP', 'CAN', 'E', 'AUF']                                                           RTRS         0.000025
# ['UKI', 'Z', 'C', 'MTL', 'PSC', 'U', 'IF', 'EMK', 'NAW', 'E']                                                                                        RTRS         0.000025
# ['PCO', 'SI', 'PCU', 'O', 'DNP', 'PSC', 'PEN', 'RNP', 'OIL', 'AUP', 'SF', 'E', 'AUF']                                                                RTRS         0.000025
# ['PCO', 'SI', 'PCU', 'O', 'DNP', 'PSC', 'PEN', 'U', 'OIL', 'RNP', 'J', 'NAW', 'AUP', 'CAN', 'E', 'AUF']                                              RTRS         0.000025
# ['PCO', 'SI', 'PCU', 'O', 'DNP', 'PSC', 'PEN', 'U', 'RNP', 'NAW', 'OIL', 'AUP', 'CAN', 'E', 'AUF']                                                   RTRS         0.000025
# ['PCO', 'PSC', 'RNP', 'NAW', 'E', 'RINVM']                                                                                                           RTRS         0.000025
# ['PCO', 'SI', 'PCU', 'O', 'U', 'RNP', 'OIL', 'E', 'AUF']                                                                                             RTRS         0.000025
# ['PCO', 'SI', 'SNI', 'PCU', 'DNP', 'PSC', 'U', 'RNP', 'NAW', 'AUP', 'SNS', 'E', 'AUF']                                                               RTRS         0.000025
# ['PCO', 'SI', 'T', 'NAT', 'D', 'RNP', 'E', 'AUF']                                                                                                    RTRS         0.000025
# ['PCO', 'SNI', 'AFN', 'DNP', 'PSC', 'RNP', 'J', 'SNS', 'E', 'SI']                                                                                    RTRS         0.000025
# ['PCO', 'SNI', 'AFN', 'PCU', 'O', 'DNP', 'PSC', 'PEN', 'U', 'RNP', 'J', 'OIL', 'SNS', 'E']                                                           RTRS         0.000025
# ['PCO', 'SNI', 'AFN', 'PCU', 'O', 'DNP', 'PSC', 'PEN', 'U', 'RNP', 'NAW', 'OIL', 'SNS', 'E']                                                         RTRS         0.000025
# ['PCO', 'SNI', 'DNP', 'PSC', 'RNP', 'SNS', 'E', 'N']                                                                                                 RTRS         0.000025
# ['PCO', 'SNI', 'DNP', 'PSC', 'U', 'RNP', 'J', 'NAW', 'SNS', 'E']                                                                                     RTRS         0.000025
#                                                                                                                                                                    ...
# ['NW', 'NBN', 'FN', 'E', 'SW', 'U', 'DA']                                                                                                            RTRS         0.018375
# ['PSC', 'U', 'J', 'NAW', 'CAN', 'E']                                                                                                                 RTRS         0.018425
# ['C', 'PCO', 'MTL', 'PCU', 'SOF', 'DNP', 'PSC', 'GRO', 'U', 'RNP', 'NAW', 'E']                                                                       RTRS         0.018449
# ['T', 'PSC', 'U', 'D', 'M', 'NAW', 'E']                                                                                                              RTRS         0.018548
# ['UKI', 'PCO', 'T', 'DNP', 'PSC', 'D', 'RNP', 'EMK', 'E']                                                                                            RTRS         0.018696
# ['T', 'PSC', 'U', 'D', 'NAW', 'E']                                                                                                                   RTRS         0.019461
# ['O', 'DNP', 'PSC', 'PEN', 'U', 'RNP', 'MF', 'OIL', 'NAW', 'PTD', 'CAN', 'E']                                                                        RTRS         0.019535
# ['T', 'DNP', 'PSC', 'U', 'D', 'M', 'EMK', 'RNP', 'NAW', 'E']                                                                                         RTRS         0.019609
# ['UKI', 'PGE', 'G', 'T', 'DNP', 'PSC', 'U', 'D', 'M', 'EMK', 'RNP', 'NAW', 'CAN', 'E']                                                               RTRS         0.019609
# ['N', 'E', 'U']                                                                                                                                      RTRS         0.019781
# ['T', 'DNP', 'PSC', 'U', 'D', 'M', 'NAW', 'E']                                                                                                       RTRS         0.019781
# ['T', 'PSC', 'U', 'D', 'M', 'EMK', 'NAW', 'E']                                                                                                       RTRS         0.019880
# ['NW', 'NBN', 'FN', 'SW', 'DA', 'E']                                                                                                                 RTRS         0.020028
# ['Z', 'PCO', 'PCU', 'DNP', 'PSC', 'U', 'RNP', 'EMK', 'NAW', 'E']                                                                                     RTRS         0.020053
# ['T', 'U', 'D', 'NAW', 'E', 'NAT']                                                                                                                   RTRS         0.020127
# ['UKI', 'C', 'MTL', 'T', 'O', 'SOF', 'DNP', 'U', 'D', 'GRO', 'M', 'EMK', 'OIL', 'E', 'NAT']                                                          RTRS         0.020201
# ['C', 'PCO', 'MTL', 'PCU', 'U', 'RNP', 'CAN', 'E']                                                                                                   RTRS         0.020299
# ['C', 'MTL', 'O', 'SOF', 'U', 'GRO', 'E']                                                                                                            RTRS         0.020472
# ['Z', 'C', 'SOF', 'PSC', 'U', 'NAW', 'E']                                                                                                            RTRS         0.020521
# ['O', 'UKI', 'E', 'U']                                                                                                                               RTRS         0.020571
# ['T', 'PSC', 'D', 'M', 'EMK', 'E']                                                                                                                   RTRS         0.020595
# ['T', 'U', 'D', 'CAN', 'E', 'NAT']                                                                                                                   RTRS         0.020719
# ['T', 'DNP', 'PSC', 'U', 'D', 'M', 'RNP', 'NAW', 'PTD', 'E']                                                                                         RTRS         0.020743
# ['CNRE', 'CNR', 'HGN', 'RNS']                                                                                                                        ONE          0.020867
# ['C', 'SOF', 'U', 'CAN', 'E']                                                                                                                        RTRS         0.020867
# ['UKI', 'PCO', 'O', 'DNP', 'ELE', 'PSC', 'PEN', 'RNP', 'EMK', 'E']                                                                                   RTRS         0.020941
# ['PCO', 'PFI', 'PCU', 'DNP', 'PSC', 'U', 'RNP', 'NAW', 'E', 'RINVM']                                                                                 RTRS         0.020965
# ['O', 'DNP', 'ELE', 'PSC', 'PEN', 'RNP', 'EMK', 'MF', 'PTD', 'E']                                                                                    RTRS         0.021113
# ...
# ['PCO', 'PCU', 'O', 'DNP', 'PSC', 'PEN', 'U', 'RNP', 'NAW', 'OIL', 'CAN', 'E']                                                                       RTRS         0.076486
# ['SNS', 'SNI']                                                                                                                                       RTRS         0.077004
# ['Z', 'O', 'PSC', 'U', 'ELN', 'NAW', 'E']                                                                                                            RTRS         0.079496
# ['UKI', 'O', 'PSC', 'U', 'ELN', 'EMK', 'NAW', 'E']                                                                                                   RTRS         0.081666
# ['Z', 'PCO', 'PCU', 'U', 'RNP', 'E']                                                                                                                 RTRS         0.081715
# ['UKI', 'T', 'D', 'M', 'E']                                                                                                                          RTRS         0.082677
# ['PCO', 'PSC', 'RNP', 'EMK', 'E']                                                                                                                    RTRS         0.084157
# ['C', 'MTL', 'SOF', 'GRO', 'U', 'E']                                                                                                                 RTRS         0.084231
# ['UKI', 'PCO', 'DNP', 'PSC', 'RNP', 'EMK', 'E']                                                                                                      RTRS         0.084675
# ['PCO', 'PCU', 'DNP', 'PSC', 'U', 'RNP', 'NAW', 'J', 'E']                                                                                            RTRS         0.085341
# ['E', 'EMK', 'NAW', 'U']                                                                                                                             RTRS         0.085982
# ['BSE']                                                                                                                                              BSE          0.094023
# ['C', 'MTL', 'U', 'CAN', 'E']                                                                                                                        RTRS         0.094245
# ['PGE', 'PCO', 'G', 'PCU', 'DNP', 'PSC', 'U', 'RNP', 'EMK', 'NAW', 'E']                                                                              RTRS         0.094985
# ['D', 'M', 'E', 'T']                                                                                                                                 RTRS         0.100338
# ['O', 'PSC', 'U', 'NAW', 'OIL', 'CAN', 'E']                                                                                                          RTRS         0.101941
# ['Z', 'E']                                                                                                                                           RTRS         0.107441
# ['O', 'PSC', 'U', 'ELN', 'NAW', 'CAN', 'E']                                                                                                          RTRS         0.107860
# ['PCO', 'T', 'PCU', 'U', 'D', 'RNP', 'E', 'NAT']                                                                                                     RTRS         0.109834
# ['CNRE', 'CNR', 'RNS']                                                                                                                               PRN          0.110426
# ['E', 'J', 'U']                                                                                                                                      RTRS         0.111091
# ['UKI', 'PSC', 'U', 'EMK', 'NAW', 'CAN', 'E']                                                                                                        RTRS         0.113755
# ['O', 'CAN', 'E', 'U']                                                                                                                               RTRS         0.114002
# ['O', 'U', 'OIL', 'CAN', 'E']                                                                                                                        RTRS         0.117652
# ['O', 'U', 'NAW', 'OIL', 'E']                                                                                                                        RTRS         0.119872
# ['T', 'DNP', 'D', 'M', 'RNP', 'E']                                                                                                                   RTRS         0.121377
# ['NW', 'UKI', 'NBN', 'BL', 'FN', 'PSC', 'E', 'SW', 'EMK', 'DA', 'N']                                                                                 RTRS         0.130256
# ['UKI', 'G', 'GRO', 'ELN', 'EMK', 'Z', 'T', 'SOF', 'MNI', 'NAW', 'J', 'NAT', 'D', 'M', 'MF', 'OIL', 'AUP', 'CAN', 'AUF', 'C', 'MTL', 'O', 'U', 'E']  RTRS         0.130330
# ['O', 'OIL', 'E', 'U']                                                                                                                               RTRS         0.132377
# ['LSEN', 'RNS']                                                                                                                                      RNS          0.133413
# ['O', 'PSC', 'U', 'NAW', 'OIL', 'E']                                                                                                                 RTRS         0.134252
# ['C', 'MTL', 'O', 'SOF', 'GRO', 'U', 'E']                                                                                                            RTRS         0.141331
# ['STXBZ']                                                                                                                                            RTRS         0.142071
# ['MTSH']                                                                                                                                             RTRS         0.143847
# ['Z', 'PCO', 'PCU', 'DNP', 'PSC', 'U', 'RNP', 'NAW', 'E']                                                                                            RTRS         0.148360
# ['PCO', 'PCU', 'O', 'U', 'RNP', 'E']                                                                                                                 RTRS         0.148558
# ['BSW', 'CNR', 'CNRA']                                                                                                                               BSW          0.148706
# ['BUZ', 'IFRF', 'FXBUZ', 'IFRFE']                                                                                                                    RTRS         0.154477
# ['SOF', 'E', 'C', 'U']                                                                                                                               RTRS         0.157782
# ['RIDJC']                                                                                                                                            RTRS         0.158498
# ['T', 'PSC', 'U', 'D', 'M', 'NAW', 'E', 'NAT']                                                                                                       RTRS         0.158572
# ['PCO', 'T', 'PCU', 'U', 'D', 'RNP', 'E']                                                                                                            RTRS         0.159386
# ['Z', 'PSC', 'U', 'NAW', 'E']                                                                                                                        RTRS         0.164393
# ['UKI', 'C', 'MTL', 'T', 'O', 'SOF', 'U', 'D', 'GRO', 'M', 'OIL', 'E', 'NAT']                                                                        RTRS         0.168956
# ['O', 'OIL']                                                                                                                                         RTRS         0.173568
# ['PCO', 'PCU', 'U', 'RNP', 'CAN', 'E']                                                                                                               RTRS         0.176824
# ['CNRE', 'CNR']                                                                                                                                      PRN          0.187381
# ['PCO', 'PCU', 'O', 'DNP', 'PSC', 'PEN', 'U', 'RNP', 'NAW', 'OIL', 'E']                                                                              RTRS         0.189798
# ['D', 'E', 'U', 'T']                                                                                                                                 RTRS         0.201045
# ['PCO', 'PCU', 'DNP', 'PSC', 'U', 'RNP', 'NAW', 'CAN', 'E']                                                                                          RTRS         0.206027
# ['DNP', 'PSC', 'RNP', 'EMK', 'MF', 'PTD', 'E']                                                                                                       RTRS         0.207285
# ['UKI', 'E']                                                                                                                                         RTRS         0.219248
# ['BUZ', 'STXBZ']                                                                                                                                     RTRS         0.226968
# ['T', 'U', 'D', 'M', 'E', 'NAT']                                                                                                                     RTRS         0.230569
# ['C', 'O', 'SOF', 'PSC', 'U', 'ELN', 'NAW', 'E']                                                                                                     RTRS         0.240213
# ['E', 'PSC', 'U']                                                                                                                                    RTRS         0.241274
# ['CCN']                                                                                                                                              MKW          0.261918
# ['UKI', 'PCO', 'PCU', 'DNP', 'PSC', 'U', 'RNP', 'EMK', 'NAW', 'E']                                                                                   RTRS         0.274202
# ['LSEN']                                                                                                                                             RNS          0.274720
# ['BSW', 'CNR', 'CNRE']                                                                                                                               BSW          0.301333
# ['PCO', 'PCU', 'DNP', 'PSC', 'U', 'RNP', 'EMK', 'NAW', 'E']                                                                                          RTRS         0.309892
# ['Z', 'E', 'U']                                                                                                                                      RTRS         0.318747
# ['UKI', 'PSC', 'U', 'EMK', 'NAW', 'E']                                                                                                               RTRS         0.334113
# ['UKI', 'E', 'U']                                                                                                                                    RTRS         0.339613
# ['UKI', 'G', 'GRO', 'ELN', 'T', 'SOF', 'MNI', 'NAW', 'J', 'NAT', 'D', 'M', 'MF', 'OIL', 'AUP', 'CAN', 'AUF', 'C', 'MTL', 'O', 'U', 'E', 'RINVM']     RTRS         0.370938
# ['D', 'E', 'T', 'U']                                                                                                                                 RTRS         0.373035
# ['HGN']                                                                                                                                              ONE          0.394789
# ['T', 'U', 'D', 'E', 'NAT']                                                                                                                          RTRS         0.401498
# ['PGE', 'PCO', 'G', 'PCU', 'DNP', 'PSC', 'U', 'RNP', 'NAW', 'E']                                                                                     RTRS         0.409934
# ['LSEN', 'RNS']                                                                                                                                      LSE          0.420170
# ['ELN', 'O', 'E', 'U']                                                                                                                               RTRS         0.438545
# ['CNR', 'CNW']                                                                                                                                       CNW          0.450014
# ['E']                                                                                                                                                RTRS         0.516265
# ['C', 'SOF', 'PSC', 'U', 'NAW', 'E']                                                                                                                 RTRS         0.652342
# ['CNRE', 'CNR', 'RNS']                                                                                                                               BSW          0.675971
# ['D', 'E', 'M', 'T']                                                                                                                                 RTRS         0.728754
# ['PSC', 'U', 'NAW', 'CAN', 'E']                                                                                                                      RTRS         0.762595
# ['O', 'E', 'U']                                                                                                                                      RTRS         0.811481
# ['LSEN']                                                                                                                                             LSE          1.164561
# ['SHKI']                                                                                                                                             HIIS         1.168187
# ['E', 'NAW', 'U']                                                                                                                                    RTRS         1.248817
# ['CNR', 'MKW']                                                                                                                                       MKW          1.467671
# ['O', 'PSC', 'U', 'ELN', 'NAW', 'E']                                                                                                                 RTRS         1.607694
# ['CAN', 'E', 'U']                                                                                                                                    RTRS         1.712792
# ['BUZ']                                                                                                                                              RTRS         1.853408
# ['PCO', 'PCU', 'DNP', 'PSC', 'U', 'RNP', 'NAW', 'E']                                                                                                 RTRS         2.220449
# ['CNR', 'GNWN']                                                                                                                                      GNW          2.464805
# ['PCO', 'PCU', 'U', 'RNP', 'E']                                                                                                                      RTRS         3.345398
# ['RITV']                                                                                                                                             RTRS         4.533317
# ['E', 'PSC', 'NAW', 'U']                                                                                                                             RTRS         4.835218
# ['BSW', 'CNR']                                                                                                                                       BSW          5.532425
# ['CNR', 'PRN']                                                                                                                                       PRN          7.519271
# ['E', 'U']                                                                                                                                           RTRS        25.241718
# Name: time, Length: 30068, dtype: float64

# %% [markdown]
# We can embed `subjects`, `audience`, `assetCodes` and headline_tokens in to vector features for the model.
# On the otherhand, if assets are embedded, we can use the average of the asset vector as feature.

# %%
distribution(news_train_df,['time','provider'],'urgency',sort=False)
# Out:
#                                      urgency
# time                      provider
# 2012-12-30 22:05:01+00:00 RTRS      0.000049
# 2012-12-30 22:10:05+00:00 RTRS      0.000025
# 2012-12-30 23:00:24+00:00 RTRS      0.000025
# 2012-12-31 00:48:34+00:00 RTRS      0.000025
# 2012-12-31 00:52:32+00:00 RTRS      0.000025
# 2012-12-31 01:06:33+00:00 RTRS      0.000025
# 2012-12-31 01:09:12+00:00 RTRS      0.000025
# 2012-12-31 01:16:33+00:00 HIIS      0.000025
# 2012-12-31 01:16:58+00:00 HIIS      0.000025
# 2012-12-31 01:18:55+00:00 RTRS      0.000025
# 2012-12-31 01:24:13+00:00 RTRS      0.000099
# 2012-12-31 02:26:41+00:00 RTRS      0.000025
# 2012-12-31 02:34:34+00:00 PRN       0.000025
# 2012-12-31 02:41:46+00:00 ACN       0.000025
# 2012-12-31 02:42:35+00:00 RTRS      0.000025
#
# let $F_{(T,i)}=[f_{(N,T,i)}^{1},...,f_{(N,T,i)}^{h}]$ be the $i$th news feautre at time step $T$ and $A_N=[a_{(N,T,i)}^{1},...,a_{(N,T,i)}^{M}]$ be the average of the vectors of the news subject, then the news matrix,
#
# $$N_{(T,i)}=[a_{(N,T,i)}^{1}*N_{(T,i)},...,a_{(N,T,i)}^{M}*N_{(T,i)}]$$,
#
# and for each asset $A=[a^{1},....,a^{M}]$ the effect of the news on the asset is,
#
# $$(A \cdot A_N)  F_{(T,i)}=N_{(T,i)}A$$.

# %% [markdown]
# ## Features engineering

# %% [markdown]
# ## Headlines

# %% [markdown]
# ## Word embeddings
#
# Embeddings mean turning certain categorical/text data into meaningful vectors that can be "ingested" by a machine learning model. Word embeddings is a very common technique used in NLP. By turning words into vectors, we can further compose a meaning representation vectors for each document.
#
# There are different models that can further encode word embeddings into a document embeddings which would be discussed later.

# %% [markdown]
# ## Document embeddings
#
# While some other models creates embeddings for words, there are also other models that can directly create embeddings for documents of various length.

# %% [markdown]
# To train for embeddings, we would first need to tokenise the headline sentences.

# %% [markdown]
# ### Word embeddings - 1. Word2Vec
# Original paper: https://arxiv.org/pdf/1310.4546.pdf
#
# Blog referece: https://www.knime.com/blog/word-embedding-word2vec-explained
#
# Further formalisation: https://papers.nips.cc/paper/5477-neural-word-embedding-as-implicit-matrix-factorization.pdf
#
# Pretrained embeddings:
#
# 1. google news: https://drive.google.com/file/d/0B7XkCwpI5KDYNlNUTTlSS21pQmM/edit
# 2. freebase entity: https://docs.google.com/file/d/0B7XkCwpI5KDYaDBDQm1tZGNDRHc/edit
#
#
# Word2Vec is one of the most famous embedding for words first [published by Google in 2013](https://arxiv.org/pdf/1310.4546.pdf). It combines the CBOW and the Skip-gram structure to form an encoder. The representation learnt is an embedded vector which encode the coocurrences probability between words and context. The model applied a numerous different technique to simplify the calculations such as `negative sampling` and `hierachical softmax` which are as well applied in other embedding models developed afterwards.
#
# It can be viewed as an auto-encoder model for context-word in terms of deep-learning or [a factorisation(approximation) of the context-words pointwise-mutual information matrix](https://papers.nips.cc/paper/5477-neural-word-embedding-as-implicit-matrix-factorization.pdf).
#
# The understanding of the latter would help combining the model with other mathematical/statistical models to generate quantified results.

# %% [markdown]
# ##### Custom embedding - Model training

# %%
from gensim.models import Word2Vec

# %%
model_w2vCustom = Word2Vec(sentences=news_train_df['headline_tokens'], size=100, window=5, min_count=5, workers=4, sg=0)
#model_w2vCustom.save('./sampleData/word2vecCustom.model')
model_w2vCustom=Word2Vec.load('./sampleData/word2vecCustom.model')

# %% [markdown]
# #### Pretrained-models

# %%
import gensim
# Load Google's pre-trained Word2Vec model.
fileDir='C:/Users/CK/Downloads/'
freebase_entity='knowledge-vectors-skipgram1000.bin'
google_news='GoogleNews-vectors-negative300.bin'
model_w2vGoogleNews = gensim.models.KeyedVectors.load_word2vec_format(fileDir+google_news, binary=True)

# %% [markdown]
# #### Transfer learning

# %%
#news_df=pd.read_csv('./sampleData/news_train.csv', encoding = "ISO-8859-1")
#Create the model
model_w2vGoogleNewsPlus=gensim.models.Word2Vec(size=300)
#Build the new vocabs
model_w2vGoogleNewsPlus.build_vocab(news_df['headline_tokens'])
#Read in the pretrained vectors
model_w2vGoogleNewsPlus.intersect_word2vec_format(fileDir+google_news, binary=True)
model_w2vGoogleNewsPlus.train(news_df['headline_tokens'],total_examples=model_NewsPlus.corpus_count,epochs=10)
model_w2vGoogleNewsPlus.save('./sampleData/word2vecTransfer.model')

# %% [markdown]
# ### Word embeddings - 2. Fastext

# %% [markdown]
# Original paper: https://arxiv.org/pdf/1607.04606.pdf
#
# Blog reference: https://towardsdatascience.com/word-embedding-with-word2vec-and-fasttext-a209c1d3e12c
#
# Pre-trained embeddings:
#     1. https://github.com/facebookresearch/fastText/blob/master/docs/crawl-vectors.md
#
# Fasttext is very similar to word2vec but instead of simply using the whole world, it splits words into subwords as inputs and sum the vectors as the embedding of the word. Such method can generalise the meaning of the words to unseen words.

# %% [markdown]
# ##### Custom embedding - Model training

# %%
from gensim.models import FastText

# %%
model_FTCustom = FastText(sentences=news_train_df['headline_tokens'], size=100, window=5, min_count=5, workers=4, sg=0)
model_FTCustom.save('./sampleData/FastTextCustom.model')
#model_FTCustom=FastText.load('./sampleData/word2vecCustom.model')

# %% [markdown]
# #### Pretrained-models

# %%
import gensim
model_FTgoogleNews = gensim.models.FastText.load_fasttext_format(fileDir+'cc.en.300.bin', binary=True)

# %% [markdown]
# #### Transfer learning

# %%
#news_train_df=pd.read_csv('./sampleData/news_train.csv', encoding = "ISO-8859-1")
model_FTgoogleNewsPlus=gensim.models.FastText(size=300)
model_FTgoogleNewsPlus.load_fasttext_format(fileDir+'cc.en.300.bin', binary=True)
model_FTgoogleNewsPlus.build_vocab(news_train_df['headline_tokens'])

# %%
model_FTgoogleNewsPlus.train(news_train_df['headline_tokens'],total_examples=model_NewsPlus.corpus_count,epochs=10)
# Out:
# (1442456173, 5314372690)

# %% [markdown]
# ### Document embedding - 1. Doc2Vec
#
# Original paper: https://arxiv.org/pdf/1405.4053.pdf
#
# blog summary: https://medium.com/scaleabout/a-gentle-introduction-to-doc2vec-db3e8c0cce5e
#
# Doc2vec is similar to word2vec. Both of them use the same techniques and encode-decoding model except that now it is embedding the document vector as one of the input vectors for CBOW and using only the document vector to reconstruct the context in skip-gram. The goal is to train the model to learn how to represent a document vector based on the content.
#
# As it is to learn the document vector summarised, the population distribution of the documents is also important. Meaning that properly control the source of the training document can better encode the meaning of the documents into vectors.

# %% [markdown]
# ##### Custom embedding - Model training

# %%
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from ast import literal_eval
documents = [TaggedDocument(literal_eval(content), [i]) for i,content in news_train_df['headline_tokens'].iteritems()]

# %%
model_d2vCustom = Doc2Vec(documents=documents,vector_size=100, window=5, min_count=1, workers=4)

# %%
model_d2vCustom.save('./sampleData/model_d2vCustom100.model')
